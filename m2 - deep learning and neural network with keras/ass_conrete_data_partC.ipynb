# %% [markdown]
# ## Deep Learning with Keras: Assignment (PART C)

# %%
# import keras libraries
import numpy as np
import pandas as pd

# %%
# load concrete dataset
concrete = pd.read_csv("concrete_data.csv")
concrete.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
# identify concrete dataset
concrete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cement              1030 non-null   float64
#  1   Blast Furnace Slag  1030 non-null   float64
#  2   Fly Ash             1030 non-null   float64
#  3   Water               1030 non-null   float64
#  4   Superplasticizer    1030 non-null   float64
#  5   Coarse Aggregate    1030 non-null   float64
#  6   Fine Aggregate      1030 non-null   float64
#  7   Age                 1030 non-null   int64
#  8   Strength            1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.6 KB

# %% [markdown]
# ### C. Increase the numbers or epochs

# %%
# import libraries for buidling neural nentwork model
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# create a deep learning model
model = Sequential()
ncols = concrete.drop(columns=["Strength"], axis=1).shape[1]

# add hidden layers
# create optimizer
model.add(Dense(10, activation="relu", input_shape = (ncols,)))
model.add(Dense(1))
model.compile(optimizer="adam", loss="mean_squared_error")
# Out:
# d:\User\LocalMachine\Anaconda\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### Model Training

# %%
# import scikit learn library for training and testing data
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
concrete.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
# normalise data
def normalise_data(data, feature):
  # detertmine the mean value and std from input feature
  x_mean = data[feature].mean()
  x_std = data[feature].std()

  # apply z score to normalise input feature's data
  x_norm = (data[feature] - x_mean)/x_std
  return x_norm

def apply_data_normalisation(data, feature_list):
  norm_data = data
  for feature in feature_list:
    feat_norm = normalise_data(data, feature)
    norm_data.loc[:,feature] = feat_norm
  return norm_data

# %%
concrete.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
concrete_norm = concrete.copy()
concrete_norm = apply_data_normalisation(concrete, concrete.columns)
concrete_norm.head()
# Out:
# C:\Users\mian_\AppData\Local\Temp\ipykernel_25928\3235113012.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.27959729 -0.27959729  3.55134048 ... -0.27959729 -0.27959729
#  -0.27959729]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   norm_data.loc[:,feature] = feat_norm
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age  Strength
# 0          0.862735       -1.217079 -0.279597  2.644123
# 1          1.055651       -1.217079 -0.279597  1.560663
# 2         -0.526262       -2.239829  3.551340  0.266498
# 3         -0.526262       -2.239829  5.055221  0.313188
# 4          0.070492        0.647569  4.976069  0.507732

# %%
# train data
concreteX = concrete_norm.drop(columns=["Strength"], axis=1)
concreteY = concrete_norm["Strength"]

conc_xtrain, conc_xtest, conc_ytrain, conc_ytest = train_test_split(concreteX, 
                                                                    concreteY, 
                                                                    test_size=0.3,)

# %%
# train the model
# retrieve all mse values + store into a mse_values
model_history = model.fit(conc_xtrain, conc_ytrain, validation_data=(conc_xtest, conc_ytest), epochs=100)
mse_values = model_history.history["val_loss"]

# predict the model
conc_pred = model.predict(conc_xtest)

# evaluate the model + create list of mse
mse = mean_squared_error(conc_ytest, conc_pred)
# Out:
# Epoch 1/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - loss: 1.3681 - val_loss: 1.4781
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2868 - val_loss: 1.2625
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0413 - val_loss: 1.1105
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0142 - val_loss: 0.9962
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8729 - val_loss: 0.9060
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7751 - val_loss: 0.8371
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7262 - val_loss: 0.7805
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6823 - val_loss: 0.7315
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5382 - val_loss: 0.6963
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5470 - val_loss: 0.6631
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5368 - val_loss: 0.6346
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5057 - val_loss: 0.6089
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4994 - val_loss: 0.5853
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4810 - val_loss: 0.5631
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4718 - val_loss: 0.5432
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4844 - val_loss: 0.5252
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4048 - val_loss: 0.5077
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4272 - val_loss: 0.4910
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4027 - val_loss: 0.4753
# Epoch 20/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4050 - val_loss: 0.4608
# Epoch 21/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3754 - val_loss: 0.4472
# Epoch 22/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3886 - val_loss: 0.4327
# Epoch 23/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3407 - val_loss: 0.4202
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3552 - val_loss: 0.4068
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3073 - val_loss: 0.3965
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3268 - val_loss: 0.3867
# Epoch 27/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3031 - val_loss: 0.3775
# Epoch 28/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2918 - val_loss: 0.3684
# Epoch 29/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2926 - val_loss: 0.3595
# Epoch 30/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2801 - val_loss: 0.3517
# Epoch 31/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2875 - val_loss: 0.3438
# Epoch 32/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2540 - val_loss: 0.3362
# Epoch 33/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2713 - val_loss: 0.3294
# Epoch 34/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2583 - val_loss: 0.3225
# Epoch 35/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2633 - val_loss: 0.3160
# Epoch 36/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2452 - val_loss: 0.3093
# Epoch 37/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2383 - val_loss: 0.3024
# Epoch 38/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2367 - val_loss: 0.2956
# Epoch 39/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2226 - val_loss: 0.2892
# Epoch 40/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2113 - val_loss: 0.2828
# Epoch 41/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2515 - val_loss: 0.2767
# Epoch 42/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2167 - val_loss: 0.2714
# Epoch 43/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2060 - val_loss: 0.2659
# Epoch 44/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2124 - val_loss: 0.2610
# Epoch 45/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2208 - val_loss: 0.2569
# Epoch 46/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1932 - val_loss: 0.2524
# Epoch 47/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2070 - val_loss: 0.2479
# Epoch 48/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1944 - val_loss: 0.2438
# Epoch 49/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1955 - val_loss: 0.2392
# Epoch 50/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1999 - val_loss: 0.2354
# Epoch 51/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1791 - val_loss: 0.2325
# Epoch 52/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1838 - val_loss: 0.2293
# Epoch 53/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1829 - val_loss: 0.2265
# Epoch 54/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1692 - val_loss: 0.2235
# Epoch 55/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1838 - val_loss: 0.2206
# Epoch 56/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1697 - val_loss: 0.2180
# Epoch 57/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1811 - val_loss: 0.2159
# Epoch 58/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1704 - val_loss: 0.2136
# Epoch 59/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1828 - val_loss: 0.2119
# Epoch 60/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1630 - val_loss: 0.2091
# Epoch 61/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1526 - val_loss: 0.2072
# Epoch 62/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1660 - val_loss: 0.2053
# Epoch 63/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1649 - val_loss: 0.2042
# Epoch 64/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1578 - val_loss: 0.2023
# Epoch 65/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1548 - val_loss: 0.2009
# Epoch 66/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1564 - val_loss: 0.1992
# Epoch 67/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1586 - val_loss: 0.1978
# Epoch 68/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1718 - val_loss: 0.1971
# Epoch 69/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1532 - val_loss: 0.1961
# Epoch 70/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1560 - val_loss: 0.1954
# Epoch 71/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1504 - val_loss: 0.1939
# Epoch 72/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1538 - val_loss: 0.1927
# Epoch 73/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1553 - val_loss: 0.1918
# Epoch 74/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1532 - val_loss: 0.1915
# Epoch 75/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1505 - val_loss: 0.1899
# Epoch 76/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1373 - val_loss: 0.1894
# Epoch 77/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1430 - val_loss: 0.1887
# Epoch 78/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1334 - val_loss: 0.1877
# Epoch 79/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1376 - val_loss: 0.1877
# Epoch 80/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1499 - val_loss: 0.1858
# Epoch 81/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1394 - val_loss: 0.1847
# Epoch 82/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1489 - val_loss: 0.1837
# Epoch 83/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1502 - val_loss: 0.1836
# Epoch 84/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1452 - val_loss: 0.1826
# Epoch 85/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1514 - val_loss: 0.1815
# Epoch 86/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1398 - val_loss: 0.1811
# Epoch 87/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1414 - val_loss: 0.1803
# Epoch 88/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1333 - val_loss: 0.1797
# Epoch 89/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1356 - val_loss: 0.1790
# Epoch 90/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1384 - val_loss: 0.1785
# Epoch 91/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1493 - val_loss: 0.1784
# Epoch 92/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1313 - val_loss: 0.1766
# Epoch 93/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1291 - val_loss: 0.1768
# Epoch 94/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1322 - val_loss: 0.1755
# Epoch 95/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1346 - val_loss: 0.1771
# Epoch 96/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1342 - val_loss: 0.1745
# Epoch 97/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1306 - val_loss: 0.1751
# Epoch 98/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1265 - val_loss: 0.1740
# Epoch 99/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1271 - val_loss: 0.1737
# Epoch 100/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1370 - val_loss: 0.1733
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
# mean squared error: result
print(f"mean squared error at (50/50): {mse}")
# Out:
# mean squared error at (50/50): 0.17326638918213413

# %%
# mse values
mse_list = mse_values
epoch_list = [e for e in range(1,len(mse_list)+1)]

print("Epoch - MSE value")
for ep, mse_val in zip(epoch_list, mse_list):
  print(f"{ep} - {mse_val}")
# Out:
# Epoch - MSE value
# 1 - 1.478148102760315
# 2 - 1.2625083923339844
# 3 - 1.110525131225586
# 4 - 0.9962260723114014
# 5 - 0.9059926271438599
# 6 - 0.8371454477310181
# 7 - 0.7804785966873169
# 8 - 0.7315096259117126
# 9 - 0.6963468790054321
# 10 - 0.6630730032920837
# 11 - 0.6345922350883484
# 12 - 0.6089112162590027
# 13 - 0.5852699875831604
# 14 - 0.5630972385406494
# 15 - 0.5431855320930481
# 16 - 0.5252379775047302
# 17 - 0.5076689124107361
# 18 - 0.49100515246391296
# 19 - 0.47532376646995544
# 20 - 0.46081918478012085
# 21 - 0.4472140669822693
# 22 - 0.4327113628387451
# 23 - 0.4201573133468628
# 24 - 0.4067680537700653
# 25 - 0.3964855968952179
# 26 - 0.3866655230522156
# 27 - 0.37751972675323486
# 28 - 0.36837247014045715
# 29 - 0.3594560921192169
# 30 - 0.35166701674461365
# 31 - 0.3437967002391815
# 32 - 0.3361669182777405
# 33 - 0.3294162452220917
# 34 - 0.3224548101425171
# 35 - 0.31595373153686523
# 36 - 0.3093407452106476
# 37 - 0.30244919657707214
# 38 - 0.2956499755382538
# 39 - 0.2892191708087921
# 40 - 0.2828259766101837
# 41 - 0.27668237686157227
# 42 - 0.271403044462204
# 43 - 0.2659043073654175
# 44 - 0.2610337734222412
# 45 - 0.2569359242916107
# 46 - 0.252447247505188
# 47 - 0.2479439377784729
# 48 - 0.24381856620311737
# 49 - 0.23924769461154938
# 50 - 0.23536242544651031
# 51 - 0.23250891268253326
# 52 - 0.22929967939853668
# 53 - 0.22652468085289001
# 54 - 0.2235354334115982
# 55 - 0.22062885761260986
# 56 - 0.2179514616727829
# 57 - 0.21585914492607117
# 58 - 0.21356186270713806
# 59 - 0.21186357736587524
# 60 - 0.20907637476921082
# 61 - 0.20717711746692657
# 62 - 0.20531857013702393
# 63 - 0.20424747467041016
# 64 - 0.20234915614128113
# 65 - 0.20091794431209564
# 66 - 0.19916343688964844
# 67 - 0.19780953228473663
# 68 - 0.19707608222961426
# 69 - 0.19614824652671814
# 70 - 0.19541214406490326
# 71 - 0.1939028650522232
# 72 - 0.19270259141921997
# 73 - 0.19184650480747223
# 74 - 0.1914997547864914
# 75 - 0.18992745876312256
# 76 - 0.18938130140304565
# 77 - 0.18865501880645752
# 78 - 0.18767230212688446
# 79 - 0.18766950070858002
# 80 - 0.18584902584552765
# 81 - 0.1846606433391571
# 82 - 0.1837140917778015
# 83 - 0.1835637092590332
# 84 - 0.18256035447120667
# 85 - 0.18148285150527954
# 86 - 0.18108823895454407
# 87 - 0.18028952181339264
# 88 - 0.1796587109565735
# 89 - 0.17895029485225677
# 90 - 0.17853906750679016
# 91 - 0.17843928933143616
# 92 - 0.1765824556350708
# 93 - 0.17680664360523224
# 94 - 0.17552778124809265
# 95 - 0.17706429958343506
# 96 - 0.17445683479309082
# 97 - 0.17513588070869446
# 98 - 0.17398688197135925
# 99 - 0.1737237423658371
# 100 - 0.17326638102531433

# %%
# mse values: mean and std
# convert epoch and mse into dataframe
# take the mean and std of it

def create_mse_dict(epoch: list, mse_val:list) -> dict:
  # create a dict for all mse values
  mse_dict = {}
  mse_sample = [epoch, mse_val]
  mse_feat = ["Epoch","MSE"]

  for feat, sample in zip(mse_feat, mse_sample):
    mse_dict[feat] = sample
  return mse_dict

def convert_mse_data(epoch, mse_val):
  mse_dict = create_mse_dict(epoch, mse_val)
  mse_data = pd.DataFrame(mse_dict)
  return mse_data

# %%
mse_dict_ = create_mse_dict(epoch_list, mse_list)
mse_data = convert_mse_data(epoch_list, mse_list)
mse_data.head()
# Out:
#    Epoch       MSE
# 0      1  1.478148
# 1      2  1.262508
# 2      3  1.110525
# 3      4  0.996226
# 4      5  0.905993

# %%
# find the statistical measurement
mse_mean = mse_data["MSE"].mean()
mse_std = mse_data["MSE"].std()
print(f"Mean value of MSE: {mse_mean:.3f}")
print(f"Standard Deviation of MSE: {mse_std:.3f}")
# Out:
# Mean value of MSE: 0.342
# Standard Deviation of MSE: 0.245

# %% [markdown]
# **How does the mean of the mean squared errors compare to that from Step A?**

# %% [markdown]
# + mean of mse from part B (without normalisation): 0.589
# + mean of mse from part C (with normalisation): 0.342

# %% [markdown]
# By increasing the number of epochs shows that the means of mse has decreased. When epoch has doubled from part B in part C, the mean value of part B has reduced from 0.589 to 0.498 in part C.
