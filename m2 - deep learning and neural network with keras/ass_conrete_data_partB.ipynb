# %% [markdown]
# ## Deep Learning with Keras: Assignment (PART B)

# %%
# import keras libraries
import numpy as np
import pandas as pd

# %%
# load concrete dataset
concrete = pd.read_csv("concrete_data.csv")
concrete.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
# identify concrete dataset
concrete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cement              1030 non-null   float64
#  1   Blast Furnace Slag  1030 non-null   float64
#  2   Fly Ash             1030 non-null   float64
#  3   Water               1030 non-null   float64
#  4   Superplasticizer    1030 non-null   float64
#  5   Coarse Aggregate    1030 non-null   float64
#  6   Fine Aggregate      1030 non-null   float64
#  7   Age                 1030 non-null   int64
#  8   Strength            1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.6 KB

# %% [markdown]
# ### B. Build a baseline model + Use Normalised Data

# %%
# import libraries for buidling neural nentwork model
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# create a deep learning model
model = Sequential()
ncols = concrete.drop(columns=["Strength"], axis=1).shape[1]

# add hidden layers
# create optimizer
model.add(Dense(5, activation="relu", input_shape = (ncols,)))
model.add(Dense(1))
model.compile(optimizer="adam", loss="mean_squared_error")
# Out:
# d:\User\LocalMachine\Anaconda\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### Model Training

# %%
# import scikit learn library for training and testing data
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
concrete.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
# normalise data
def normalise_data(data, feature):
  # detertmine the mean value and std from input feature
  x_mean = data[feature].mean()
  x_std = data[feature].std()

  # apply z score to normalise input feature's data
  x_norm = (data[feature] - x_mean)/x_std
  return x_norm

def apply_data_normalisation(data, feature_list):
  norm_data = data
  for feature in feature_list:
    feat_norm = normalise_data(data, feature)
    norm_data.loc[:,feature] = feat_norm
  return norm_data

# %%
concrete.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
concrete_norm = concrete.copy()
concrete_norm = apply_data_normalisation(concrete, concrete.columns)
concrete_norm.head()
# Out:
# C:\Users\mian_\AppData\Local\Temp\ipykernel_31392\3235113012.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.27959729 -0.27959729  3.55134048 ... -0.27959729 -0.27959729
#  -0.27959729]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   norm_data.loc[:,feature] = feat_norm
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age  Strength
# 0          0.862735       -1.217079 -0.279597  2.644123
# 1          1.055651       -1.217079 -0.279597  1.560663
# 2         -0.526262       -2.239829  3.551340  0.266498
# 3         -0.526262       -2.239829  5.055221  0.313188
# 4          0.070492        0.647569  4.976069  0.507732

# %%
# train data
concreteX = concrete_norm.drop(columns=["Strength"], axis=1)
concreteY = concrete_norm["Strength"]

conc_xtrain, conc_xtest, conc_ytrain, conc_ytest = train_test_split(concreteX, 
                                                                    concreteY, 
                                                                    test_size=0.3,)

# %%
# train the model
# retrieve all mse values + store into a mse_values
model_history = model.fit(conc_xtrain, conc_ytrain, validation_data=(conc_xtest, conc_ytest), epochs=50)
mse_values = model_history.history["val_loss"]

# predict the model
conc_pred = model.predict(conc_xtest)

# evaluate the model + create list of mse
mse = mean_squared_error(conc_ytest, conc_pred)
# Out:
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 1.5190 - val_loss: 1.4307
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3070 - val_loss: 1.3196
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2705 - val_loss: 1.2306
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0253 - val_loss: 1.1634
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0431 - val_loss: 1.0958
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0023 - val_loss: 1.0382
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9125 - val_loss: 0.9849
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8649 - val_loss: 0.9360
# Epoch 9/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8288 - val_loss: 0.8879
# Epoch 10/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7655 - val_loss: 0.8393
# Epoch 11/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7741 - val_loss: 0.7942
# Epoch 12/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7078 - val_loss: 0.7517
# Epoch 13/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6016 - val_loss: 0.7125
# Epoch 14/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6136 - val_loss: 0.6727
# Epoch 15/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6497 - val_loss: 0.6381
# Epoch 16/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6111 - val_loss: 0.6093
# Epoch 17/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5243 - val_loss: 0.5855
# Epoch 18/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5333 - val_loss: 0.5629
# Epoch 19/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4750 - val_loss: 0.5435
# Epoch 20/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4613 - val_loss: 0.5290
# Epoch 21/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4821 - val_loss: 0.5134
# Epoch 22/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4207 - val_loss: 0.5016
# Epoch 23/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4238 - val_loss: 0.4890
# Epoch 24/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4398 - val_loss: 0.4776
# Epoch 25/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4594 - val_loss: 0.4679
# Epoch 26/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4383 - val_loss: 0.4593
# Epoch 27/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4158 - val_loss: 0.4514
# Epoch 28/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3847 - val_loss: 0.4431
# Epoch 29/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3691 - val_loss: 0.4360
# Epoch 30/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3804 - val_loss: 0.4287
# Epoch 31/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3797 - val_loss: 0.4216
# Epoch 32/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3944 - val_loss: 0.4157
# Epoch 33/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3743 - val_loss: 0.4091
# Epoch 34/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3387 - val_loss: 0.4029
# Epoch 35/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3381 - val_loss: 0.3965
# Epoch 36/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3580 - val_loss: 0.3907
# Epoch 37/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3218 - val_loss: 0.3866
# Epoch 38/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3023 - val_loss: 0.3822
# Epoch 39/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2858 - val_loss: 0.3774
# Epoch 40/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3103 - val_loss: 0.3730
# Epoch 41/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3372 - val_loss: 0.3681
# Epoch 42/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3006 - val_loss: 0.3643
# Epoch 43/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3444 - val_loss: 0.3602
# Epoch 44/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3201 - val_loss: 0.3562
# Epoch 45/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2897 - val_loss: 0.3525
# Epoch 46/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3138 - val_loss: 0.3497
# Epoch 47/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2911 - val_loss: 0.3462
# Epoch 48/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3070 - val_loss: 0.3442
# Epoch 49/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2752 - val_loss: 0.3412
# Epoch 50/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3043 - val_loss: 0.3388
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
# mean squared error: result
print(f"mean squared error at (50/50): {mse}")
# Out:
# mean squared error at (50/50): 0.33882612534787065

# %%
# mse values
mse_list = mse_values
epoch_list = [e for e in range(1,len(mse_list)+1)]

print("Epoch - MSE value")
for ep, mse_val in zip(epoch_list, mse_list):
  print(f"{ep} - {mse_val}")
# Out:
# Epoch - MSE value
# 1 - 1.4306682348251343
# 2 - 1.3195760250091553
# 3 - 1.2305784225463867
# 4 - 1.1633884906768799
# 5 - 1.0958470106124878
# 6 - 1.038169026374817
# 7 - 0.9849076271057129
# 8 - 0.935964047908783
# 9 - 0.887898862361908
# 10 - 0.8393442034721375
# 11 - 0.7942368388175964
# 12 - 0.7517083287239075
# 13 - 0.7124555706977844
# 14 - 0.672663688659668
# 15 - 0.6381121873855591
# 16 - 0.6093049645423889
# 17 - 0.5855404138565063
# 18 - 0.5628821849822998
# 19 - 0.5435333847999573
# 20 - 0.528987467288971
# 21 - 0.5134493112564087
# 22 - 0.5015997290611267
# 23 - 0.48901045322418213
# 24 - 0.47762346267700195
# 25 - 0.46786069869995117
# 26 - 0.45927953720092773
# 27 - 0.4514012038707733
# 28 - 0.44308334589004517
# 29 - 0.43595895171165466
# 30 - 0.4287061095237732
# 31 - 0.42159998416900635
# 32 - 0.4157083332538605
# 33 - 0.40912285447120667
# 34 - 0.4029211699962616
# 35 - 0.39647799730300903
# 36 - 0.39065787196159363
# 37 - 0.38655582070350647
# 38 - 0.382201224565506
# 39 - 0.377448707818985
# 40 - 0.37300166487693787
# 41 - 0.36813563108444214
# 42 - 0.36431628465652466
# 43 - 0.36019277572631836
# 44 - 0.35622724890708923
# 45 - 0.3525206744670868
# 46 - 0.34969595074653625
# 47 - 0.3462091088294983
# 48 - 0.3441919982433319
# 49 - 0.341187447309494
# 50 - 0.33882609009742737

# %%
# mse values: mean and std
# convert epoch and mse into dataframe
# take the mean and std of it

def create_mse_dict(epoch: list, mse_val:list) -> dict:
  # create a dict for all mse values
  mse_dict = {}
  mse_sample = [epoch, mse_val]
  mse_feat = ["Epoch","MSE"]

  for feat, sample in zip(mse_feat, mse_sample):
    mse_dict[feat] = sample
  return mse_dict

def convert_mse_data(epoch, mse_val):
  mse_dict = create_mse_dict(epoch, mse_val)
  mse_data = pd.DataFrame(mse_dict)
  return mse_data

# %%
mse_dict_ = create_mse_dict(epoch_list, mse_list)
mse_data = convert_mse_data(epoch_list, mse_list)
mse_data.head()
# Out:
#    Epoch       MSE
# 0      1  1.430668
# 1      2  1.319576
# 2      3  1.230578
# 3      4  1.163388
# 4      5  1.095847

# %%
# find the statistical measurement
mse_mean = mse_data["MSE"].mean()
mse_std = mse_data["MSE"].std()
print(f"Mean value of MSE: {mse_mean:.3f}")
print(f"Standard Deviation of MSE: {mse_std:.3f}")
# Out:
# Mean value of MSE: 0.589
# Standard Deviation of MSE: 0.288

# %% [markdown]
# **How does the mean of the mean squared errors compare to that from Step A?**

# %% [markdown]
# + mean of mse from part A (without normalisation): 23756.258
# + mean of mse from part B (with normalisation): 0.589
